# %%
pip install google-api-python-client
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from googleapiclient.discovery import build

# Set your YouTube Data API key here
API_KEY = "AIzaSyA0vaLuQ-hogdwCoGY5-XcP8itCY4MwPzQ"

# Initialize the YouTube Data API client
youtube = build('youtube', 'v3', developerKey=API_KEY)

def search_channels_by_keywords(keywords, max_results=10):
    # Search for channels using the provided keywords
    search_response = youtube.search().list(
        q=keywords,
        type='channel',
        part='id,snippet',
        maxResults=max_results
    ).execute()

    # Extract channel information from the search response
    channels = []
    for item in search_response.get('items', []):
        channel = {
            'channel_id': item['id']['channelId'],
            'title': item['snippet']['title'],
            'description': item['snippet']['description']
        }
        channels.append(channel)

    return channels

if __name__ == "__main__":
    search_keywords = "IIIT NUZVID"
    max_results = 100

    found_channels = search_channels_by_keywords(search_keywords, max_results)

    print(f"Found {len(found_channels)} channels related to '{search_keywords}':")
    for channel in found_channels:
        print(f"Title: {channel['title']}")
        print(f"Channel ID: {channel['channel_id']}")
        print(f"Description: {channel['description']}")
        print("=" * 30)
# Out:
# Found 50 channels related to 'IIIT NUZVID':
# Title: Cygnus IIIT Nuzvid
# Channel ID: UCoQQiY3PggymOcRY_YOOTig
# Description: This is the Official channel about Cygnus -IIIT Nuzvid In this channel we can see Latest videos about Nuzvid IIIT Fests , Dance ...
# ...
# Title: IIIT NUZVID
# Channel ID: UCrfoCv2p82a3haJga4Lu9bw
# Description: This channel is all about to motivate and to give updated info to all future Aspirants.
# ...
# Title: 𝑩𝑱𝑫 𝒇𝒓𝒐𝒎 𝑩𝑷𝑴
# Channel ID: UC3_ccsAS9ARzYNnc0b8lZNA
# Description: My Self JOHN DEVADAS from IIIT NUZVID.For BUSINESS related enquiries and PROMOTIONS,MAIL me ...
# ...
# Title: PERFORMING ARTS IIIT-NUZVID
# Channel ID: UCr6R-J4uS9v25NyGRhkcl5Q
# Description:
# ...
# Title: Transportation Engineering Laboratory IIIT Nuzvid
# Channel ID: UCuiFR2Fok-T3MR1UtPSDXhw
# Description:
# ...
# Title: AP IIIT NUZVID(EEE)
# Channel ID: UCMxcT_xKaISVhAaEjhURJsw
# Description:
# ...
# Title: RGUKT IIIT, NUZVID
# Channel ID: UCeaIOquSRw0loTwD86JIhlg
# Description:
# ...
# Title: NCC IIIT-NUZVID
# ...
